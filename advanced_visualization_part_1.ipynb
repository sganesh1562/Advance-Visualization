# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
iris=snr.load_dataset('iris') #iris is available by default inside the seaborn library

# %% [markdown]
# .head() -- only first 5 rows will be displayed (by default)
#
# .head(10) -- first 10 rows will be displayed
#
#
# .tail() -- only last 5 rows will be displayed (by default)
#
# .tail(10) -- last 10 rows will be displayed

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax=iris.plot(figsize=(15,8),title='iris dataset')

# %%
iris.plot(kind='bar')

# %%
iris['petal_length'].plot(kind='bar')

# %%
iris['sepal_width'].plot(kind='bar')

# %%
iris['sepal_width'].plot(kind='hist',stacked=True,bins=50)

# %%
iris['petal_width'].plot(kind='hist',stacked=True,bins=50)

# %%
iris['sepal_length'].plot(kind='hist',stacked=True,bins=50)

# %%
iris['petal_length'].plot(kind='hist',stacked=True,bins=50)

# %%
iris.plot(kind='hist',stacked=True,bins=50)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df=iris.drop(['species'],axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
d=df.iloc[0] #0th row will be fetched

# %%
d.head()
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,10))

# %%
d=df.iloc[80] #80th row will be fetched

# %%
d.head()
# Out:
# sepal_length    5.5
# sepal_width     2.4
# petal_length    3.8
# petal_width     1.1
# Name: 80, dtype: float64

# %%
d.plot.pie(figsize=(10,10))

# %%
d=df.head(3) #first 3 rows of df column will be fetched and stored inside 'd'

# %%
d.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
d.plot.pie(subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5309215d0>,
# ...
#       dtype=object)

# %%
df.plot.pie(subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff52ea972d0>,
# ...
#       dtype=object)
